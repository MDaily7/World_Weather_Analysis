# %%
#Dependencies and Setup
import requests
import gmaps
#import api key
from config import g_key
from pprint import pprint

# %%
# Set the parameters to search for a hotel in Paris
parameters = {'radius':5000, 'type':'lodging', 'key':g_key, 'location':'48.8566, 2.3522'}
# use the base url to search for hotels in Paris
base_url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'
#make request and get the json data from the search
hotels = requests.get(base_url, params=parameters).json()

pprint(hotels)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uECr7Dwwz0_MydgqwA3wNahZZ48u5tVyUqns3CGOtWFU183QnIKiIdGIn4zH-FrUCWXxwxvglffc-EyyevzyZ6dvdtFBJQdJiZkWhqTbwtXK6b_HYCrXLvwjr98W2pYJlTUgFdDlPfPILBuM6F6DzbU7UtPL0BqFpFCvoTd-t6lRL3_l8fuLKM7QdG2iYZf3OKYigBiZQEViNoqUpzMUu2cEpnzT7S4o_Yi_UpqutQ8wg0mcS7ZwVH-lKMAZO_gqooJGxlx1_L969WZ20_1071uxuNVO8OR6RloT99ZH6i47WQwC_sxRFui_CFHjmof7xEK3w6u6NhRfx2-Yo7CdBkCSKDow2V1Fuie4HrVce2M_Px_hpHecUdS56g1vKmGpsNkVzzZOl6t85HoTGp5iInzwtVOEmTsDcDVL4GPRhTio0gJ5rf3g81Ox',
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#                            'viewport': {'northeast': {'lat': 48.8594360302915,
#                                                       'lng': 2.354355480291502},
#                                         'southwest': {'lat': 48.8567380697085,
#                                                       'lng': 2.351657519708498}}},
# ...

# %%
# get the number of results with the len()
len(hotels['results'])
# Out:
# 20
